# %% [markdown]
# # Python Language Basics, IPython, and Jupyter Notebooks

# %% [markdown]
# > Note :  Python concepts that this chapter does not cover, like classes and object-oriented programming, which you may find useful in your foray into data analysis in Python.

# %% [markdown]
# - Python Cookbook, Third Edition, by David Beazley and Brian K. Jones (O'Reilly)
#
# - Fluent Python by Luciano Ramalho (O'Reilly)
#
# - Effective Python by Brett Slatkin (Pearson)Python Cookbook, Third Edition, by David Beazley and Brian K. Jones (O'Reilly)

# %% [markdown]
# ## Terminal

# %% [markdown]
# -  The terminal is a text interface for executing text-based programs
#
# -  commonlyy referred as CLI tools — command line interface tools
#
# -  Using the terminal (or command line) on Windows has traditionally not been as simple or easy as on other operating systems.
#
# - Better programs exist for providing a terminal experience on Windows, such as Powershell  and Gitbash (which comes as part of the git for Windows toolset)
#
# - he best option for Windows in the modern day is the Windows Subsystem for Linux ([WSL](https://docs.microsoft.com/en-us/windows/wsl/install)) — a compatibility layer for running Linux operating systems directly from inside Windows 10, allowing you to run a "true terminal" directly on Windows, without needing a virtual machine.  Watch Youtube tutorial to install WSL [here](https://www.youtube.com/watch?v=j_fd0SApJD0) or [here](https://www.youtube.com/watch?v=_fntjriRe48)

# %% [markdown]
# ### File and directory Linux commands

# %% [markdown]
# - whoami
# - pwd : print the name of the present/current working directory starting from the root.
# - ls : list files or directories
# - mkdir : allows users to create directories or folders
# - rm: The rm(remove) command is used to remove objects such as files, directories, symbolic links etc from the file system.
# - touch: Create a new file
# - cat: The cat command is used to create single or multiple files, view contain of file, concatenate files and redirect output in terminal or files.
# - more : Show contents of a file

# %% [markdown]
# ### Some of cools tools

# %% [markdown]
# - [Ohmy-Zsh](https://ohmyz.sh)
#
# - [tldr](https://github.com/tldr-pages/tldr)
#
# - [Fig](https://fig.io) --currently suppor mac, will soon support linux

# %% [markdown]
# ## The Python Interpreter

# %% [markdown]
# > Python is an interpreted language. The Python interpreter runs a program by executing one statement at a time. The standard interactive Python interpreter can be invoked on the command line with the python command:

# %% [markdown]
# - Python is interpreted language
# - How to Invoke python interpreter? ()
# - How to run python file (same or diff directory)?
# - How to invoke Ipython?
# - How to run python file using ipytho

# %% [markdown]
# ## Interrupting running code

# %% [markdown]
# > Pressing Ctrl-C while any code is running, will cause a KeyboardInterrupt to be raised. This will cause nearly all Python programs to stop immediately except in certain unusual cases.

# %% [markdown]
# ## IPython Basics

# %% [markdown]
# - Tab Completion (on objects)
#   - Install Intellisence Extension
#   - public
#   - private

# %%
a = [1,3,4,5]

# %% [markdown]
# Public

# %%
a.

# %%
a
# Out:
# [1, 3, 4, 5, 2]

# %% [markdown]
# private

# %%
a._

# %% [markdown]
# - When typing anything that looks like a file path, pressing the Tab key will complete anything on your computer’s filesystem matching what you’ve typed: (e.g code-snipped)

# %% [markdown]
# ### Introspection

# %% [markdown]
# - Using a question mark (?) before or after a variable will display some general information about the object:
#
# - Using ?? will also show the function’s source code if possible:

# %%
a = [1,3,4]

# %%
a?
# Out:
# Type:        list
# String form: [1, 3, 4]
# Length:      3
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
def add_numbers(a, b):
    """
    Add two numbers together

    Returns
    -------
    the_sum : type of arguments
    """
    return a + b

# %%
add_numbers??
# Out:
# Signature: add_numbers(a, b)
# Source:
# def add_numbers(a, b):
#     """
#     Add two numbers together
#
#     Returns
#     -------
#     the_sum : type of arguments
#     """
#     return a + b
# File:      /var/folders/l_/499_8k_5387b9tz3wp5g8lg00000gn/T/ipykernel_15995/1411870314.py
# Type:      function

# %% [markdown]
# ### Executing Code from the Clipboard

# %%
x = 5
y = 7
if x > 5:
    x += 1

    y = 8

# %%
# %cpaste

# %% [markdown]
# ### About Magic Commands

# %% [markdown]
# > IPython's special commands (which are not built into Python itself) are known as “magic” commands. These are designed to facilitate common tasks and enable you to easily control the behavior of the IPython system. A magic command is any command prefixed by the percent symbol %

# %%
# %pwd
# Out:
# '/Users/shamsuddeenmuhammad/Documents/VScode/pydata-book'

# %%
pwd
# Out:
# '/Users/shamsuddeenmuhammad/Documents/VScode/pydata-book'

# %%
# %automagic
# Out:
# Automagic is OFF, % prefix IS needed for line magics.

# %%
# %pwd
# Out:
# '/Users/shamsuddeenmuhammad/Documents/VScode/pydata-book'

# %%
import numpy as np
a = np.random.randn(100, 100)

# %%
# %timeit np.dot(a, a)
# Out:
# 24.7 ms ± 1.72 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %ls
# Out:
# COPYING                  ch04.ipynb               ch12.ipynb
# README.md                ch05.ipynb               ch13.ipynb
# __pycache__/             ch06.ipynb               ch14.ipynb
# add.py                   ch07.ipynb               images/
# appa.ipynb               ch08.ipynb               pythonml.code-workspace
# ch01.ipynb               ch09.ipynb               requirements.txt
# ch02.ipynb               ch10.ipynb               some_module.py
# ch03.ipynb               ch11.ipynb

# %% [markdown]
# ### Matplotlib Integration

# %% [markdown]
# In Jupyter

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# ## Python Language Basics

# %% [markdown]
# #### Indentation, not braces

# %% [markdown]
# > A colon denotes the start of an indented code block after which all of the code must be indented by the same amount until the end of the block

# %%
array = [1,3,4]

for x in array:
    print(x)
# Out:
# 1
# 3
# 4

# %% [markdown]
# > Love it or hate it, significant whitespace is a fact of life for Python programmers. While it may seem foreign at first, you will hopefully grow accustomed in time.

# %% [markdown]
# ### Multiple Line Statement

# %%
a = 5
b = 6 
c = 7

# %%
a = 5; b = 6; c = 7

# %% [markdown]
# #### Everything is an object

# %% [markdown]
# > Every number, string, data structure, function, class, module, and so on exists in the Python interpreter in its own “box,” which is referred to as a Python object.

# %% [markdown]
# #### Function and object method calls

# %% [markdown]
# > Almost every object in Python has attached functions, known as methods, that have access to the object’s internal contents. You can call them using dot syntax

# %%
def name(a, b):
    # comment:
    return a + b 
# end def

# %%
name(1,4)
# Out:
# 5

# %%
a =  [1,3,4]

# %%
a.append(2)

# %%
a
# Out:
# [1, 3, 4, 2]

# %%
a = (1,3,4)

# %%
a.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/shamsuddeenmuhammad/Documents/VScode/pydata-book/ch02.ipynb Cell 65' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/shamsuddeenmuhammad/Documents/VScode/pydata-book/ch02.ipynb#ch0000196?line=0'>1</a> a.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
a = [1,2,3]
a.

# %% [markdown]
# #### Attributes and methods

# %% [markdown]
# > Objects in Python typically have both attributes (other Python objects stored “inside” the object) and methods (functions associated with an object that can have access to the object’s internal data)

# %%
b = "Kaduna"

# %%
b.upper()
# Out:
# 'KADUNA'

# %%
b.islower()
# Out:
# False

# %%
c = {a:1, b:4}

# %%
c.

# %%
dir(c)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
def dirplus(obj):
    return [x for x in dir(obj) if not x.startswith('__')]

# %%
dirplus(c)
# Out:
# ['clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
c.popitem()

# %% [markdown]
# #### Importing Python Module

# %% [markdown]
# > If we wanted to access the variables and functions defined in some_module.py, from another file in the same directory we could do

# %%
import some_module
some_module.addition(5)
# Out:
# 10

# %% [markdown]
# > Or equivalently:

# %%
from some_module import addition
addition(5)
# Out:
# 10

# %% [markdown]
# > By using the as keyword you can give imports different variable names:

# %%
from some_module import addition as add
add(5)
# Out:
# 10

# %%
from some_module import *

# %%
mul(2,3)
# Out:
# 6

# %%
pi = some_module.PI
print(pi)

# %% [markdown]
# #### Accessing an attribute

# %%
import some_module

pi = some_module.PI

print(pi)

# %% [markdown]
# #### Binary operators and comparisons

# %%
5 - 7
12 + 21.5
5 <= 2

# %%
a = [1,2,4]

# %%
a = [1, 2, 3]
b = a
c = list(a)
a is b
a is not c

# %%
a == c

# %%
a = None
a is None

# %% [markdown]
# #### Mutable and immutable objects

# %% [markdown]
# > Most objects in Python, such as lists, dicts, NumPy arrays, and most user-defined types (classes), are mutable. This means that the object or values that they contain can be modified

# %%
a_list = ['foo', 2, [4, 5]]
a_list.append(1)
a_list
# Out:
# ['foo', 2, [4, 5], 1]

# %%
a_tuple = (3, 5, (4, 5))
a_tuple[1] = 'four'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/shamsuddeenmuhammad/Documents/VScode/pydata-book/ch02.ipynb Cell 100' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/shamsuddeenmuhammad/Documents/VScode/pydata-book/ch02.ipynb#ch0000099?line=0'>1</a> a_tuple = (3, 5, (4, 5))
# ----> <a href='vscode-notebook-cell:/Users/shamsuddeenmuhammad/Documents/VScode/pydata-book/ch02.ipynb#ch0000099?line=1'>2</a> a_tuple[1] = 'four'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Scalar Types

# %% [markdown]
# #### Numeric types

# %%
ival = 17239871
ival ** 6

# %%
fval = 7.243
fval2 = 6.78e-5

# %%
3 / 2

# %%
3 // 2

# %% [markdown]
# #### Strings

# %% [markdown]
# a = 'one way of writing a string'
# b = "another way"

# %%
c = "this is good"

# %%
c = """
This is a longer string that
spans multiple lines
"""

# %%
c.count('\n')

# %% [markdown]
# > string is immutable

# %%
a = 'this is a string'
a[10] = 'f'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/shamsuddeenmuhammad/Documents/VScode/pydata-book/ch02.ipynb Cell 113' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/shamsuddeenmuhammad/Documents/VScode/pydata-book/ch02.ipynb#ch0000110?line=0'>1</a> a = 'this is a string'
# ----> <a href='vscode-notebook-cell:/Users/shamsuddeenmuhammad/Documents/VScode/pydata-book/ch02.ipynb#ch0000110?line=1'>2</a> a[10] = 'f'
#
# TypeError: 'str' object does not support item assignment

# %%
b = a.replace('string', 'longer string')
b
# Out:
# 'this is a longer string'

# %% [markdown]
# > convertion of python object

# %%
a = 5.6
s = str(a)
s
# Out:
# '5.6'

# %%
s = 'python'
list(s)
s[:3]

# %%
s = '12\\34'
print(s)

# %%
s = r'this\has\no\special\characters'
s

# %%
a = 'this is the first half '
b = 'and this is the second half'
a + b

# %% [markdown]
# > String templating or formatting using f string

# %%
age = 32

print(f'his age is {age}')
# Out:
# his age is 32

# %%
price = 32.34565

print(f'The price is {price:.2f}')
# Out:
# The price is 32.35

# %% [markdown]
# #### Bytes and Unicode

# %%
val = "español"
val

# %%
val_utf8 = val.encode('utf-8')
val_utf8
type(val_utf8)

# %%
val_utf8.decode('utf-8')

# %%
val.encode('latin1')
val.encode('utf-16')
val.encode('utf-16le')

# %%
bytes_val = b'this is bytes'
bytes_val
decoded = bytes_val.decode('utf8')
decoded  # this is str (Unicode) now

# %% [markdown]
# #### Booleans

# %%
True and True
False or True

# %% [markdown]
# #### Type casting

# %%
s = '3.14159'
fval = float(s)
type(fval)
int(fval)
bool(fval)
bool(0)

# %% [markdown]
# #### None

# %%
a = None
a is None
b = 5
b is not None

# %% [markdown]
# def add_and_maybe_multiply(a, b, c=None):
#     result = a + b
#
#     if c is not None:
#         result = result * c
#
#     return result

# %%
type(None)

# %% [markdown]
# #### Dates and times

# %%
from datetime import datetime, date, time
dt = datetime(2011, 10, 29, 20, 30, 21)
dt.day
dt.minute

# %%
dt.date()
dt.time()

# %%
dt.strftime('%m/%d/%Y %H:%M')

# %%
datetime.strptime('20091031', '%Y%m%d')

# %%
dt.replace(minute=0, second=0)

# %%
dt2 = datetime(2011, 11, 15, 22, 30)
delta = dt2 - dt
delta
type(delta)

# %%
dt
dt + delta

# %% [markdown]
# ### Control Flow

# %% [markdown]
# #### if, elif, and else

# %% [markdown]
# if x < 0:
#     print('It's negative')

# %% [markdown]
# if x < 0:
#     print('It's negative')
# elif x == 0:
#     print('Equal to zero')
# elif 0 < x < 5:
#     print('Positive but smaller than 5')
# else:
#     print('Positive and larger than or equal to 5')

# %%
a = 5; b = 7
c = 8; d = 4
if a < b or c > d:
    print('Made it')

# %%
4 > 3 > 2 > 1

# %% [markdown]
# #### for loops

# %% [markdown]
# for value in collection:
#     # do something with value

# %% [markdown]
# sequence = [1, 2, None, 4, None, 5]
# total = 0
# for value in sequence:
#     if value is None:
#         continue
#     total += value

# %% [markdown]
# sequence = [1, 2, 0, 4, 6, 5, 2, 1]
# total_until_5 = 0
# for value in sequence:
#     if value == 5:
#         break
#     total_until_5 += value

# %%
for i in range(4):
    for j in range(4):
        if j > i:
            break
        print((i, j))

# %% [markdown]
# for a, b, c in iterator:
#     # do something

# %% [markdown]
# #### while loops

# %% [markdown]
# x = 256
# total = 0
# while x > 0:
#     if total > 500:
#         break
#     total += x
#     x = x // 2

# %% [markdown]
# #### pass

# %% [markdown]
# if x < 0:
#     print('negative!')
# elif x == 0:
#     # TODO: put something smart here
#     pass
# else:
#     print('positive!')

# %% [markdown]
# #### range

# %%
range(10)
list(range(10))

# %%
list(range(0, 20, 2))
list(range(5, 0, -1))

# %% [markdown]
# seq = [1, 2, 3, 4]
# for i in range(len(seq)):
#     val = seq[i]

# %% [markdown]
# sum = 0
# for i in range(100000):
#     # % is the modulo operator
#     if i % 3 == 0 or i % 5 == 0:
#         sum += i

# %% [markdown]
# #### Ternary expressions

# %% [markdown]
# value =

# %% [markdown]
# if

# %%
x = 5
'Non-negative' if x >= 0 else 'Negative'
